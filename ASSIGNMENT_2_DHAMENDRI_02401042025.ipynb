# %%
#Calculate the Sum of first 10 natural numbers
sum=0
for i in range(1,11):
 sum+=i
 print("Sum of first 10 natural numbers=",sum)

#Program for factorial of a number
n=int(input("Enter a number:"))
fact=1
for i in range(1,n+1):
  fact*=i
  print("Factorial=",fact)

#Program for fibonacci series
n=int(input("Enter a number:"))
a=0
b=1
print("Fibonacci series:")
for i in range(n):
  print(a,end="")
  c=a+b
  a=b
  b=c

#Program largest among three number
a=int(input("Enter first number:"))
b=int(input("Enter second number: "))
c=int(input("Enter third number:"))

if a>=b and a>=c:
 largest=a
elif b>=a and b>=c:
 largest=b
else:
  largest=c

print("Largest number=",largest)

#Program for student result
name=input("Enter Student name:")
roll=input("Enter roll numbers:")
total=0
subjects=5
for i in range(1,subjects+1):
 marks=float(input(f"Enter marks of Subject{i}:"))
total+=marks
percentage=total/subjects

if percentage>=90:
  grade="A"
elif percentage>=80:
  grade="B"
elif percentage>=70:
  grade="C"
elif percentage>=60:
  grade="D"
else:
  grade="Fail"
print("\n-----RESULT-----")
print("Name:",name)
print("ROLL NO:",roll)
print("Total marks:",total)
print("Percentage:",percentage)
print("Grade:",grade)
# Out:
# Sum of first 10 natural numbers= 1
# Sum of first 10 natural numbers= 3
# Sum of first 10 natural numbers= 6
# Sum of first 10 natural numbers= 10
# Sum of first 10 natural numbers= 15
# Sum of first 10 natural numbers= 21
# Sum of first 10 natural numbers= 28
# Sum of first 10 natural numbers= 36
# Sum of first 10 natural numbers= 45
# Sum of first 10 natural numbers= 55
# Enter a number:10
# Factorial= 1
# Factorial= 2
# Factorial= 6
# Factorial= 24
# Factorial= 120
# Factorial= 720
# Factorial= 5040
# Factorial= 40320
# Factorial= 362880
# Factorial= 3628800
# Enter a number:10
# Fibonacci series:
# 0112358132134Enter first number:10
# Enter second number: 65
# Enter third number:90
# Largest number= 90
# Enter Student name:MEENAKSHI
# Enter roll numbers:154
# Enter marks of Subject1:80
# Enter marks of Subject2:97
# Enter marks of Subject3:85
# Enter marks of Subject4:75
# Enter marks of Subject5:88
#
# -----RESULT-----
# Name: MEENAKSHI
# ROLL NO: 154
# Total marks: 88.0
# Percentage: 17.6
# Grade: Fail
