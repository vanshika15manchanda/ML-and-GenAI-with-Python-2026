# %%
# question : find the area of rectangle
# Area of Rectangle

length = 5
breadth = 10

area = length * breadth

print("Area of rectangle =", area)
#question : find simple interest
# Simple Interest Program

p = 50000
r = 0.20
t = 2

si = (p * r * t) / 100

print("Simple Interest =", si)
#question : convert temperature from celsius to farenheit
# Celsius to Fahrenheit Conversion

celsius = 37

fahrenheit = (celsius * 9/5) + 32

print("Temperature in Fahrenheit =", fahrenheit)
#question : calculate average of three numbers
# Average of 3 Numbers

num1 = 8
num2 = 9
num3 = 10

average = (num1 + num2 + num3) / 3

print("Average =", average)
#question : find square and cube of a number
# Square and Cube Program

num = 5

square = num ** 2
cube = num ** 3

print("Square =", square)
print("Cube =", cube)
#question : swap two numbers without third variable
# Swap Two Numbers Without Third Variable

a = 3
b = 5

a = a + b
b = a - b
a = a - b

print("After swapping:")
print("a =", a)
print("b =", b)
#question : create a student report program that takes student details using
#input(), store marks in variables , calculate total and percentage , use
#comments , use proper indentation.
# Student Report Program

# Taking student details
name = input("Enter student name: ")
roll_no = input("Enter roll number: ")

# Taking marks of 3 subjects
mark1 = float(input("Enter marks of Subject 1: "))
mark2 = float(input("Enter marks of Subject 2: "))
mark3 = float(input("Enter marks of Subject 3: "))

# Calculating total
total = mark1 + mark2 + mark3

# Calculating percentage
percentage = total / 3

# Displaying report
print("\n----- Student Report -----")
print("Student Name:", name)
print("Roll Number:", roll_no)
print("Total Marks:", total)
print("Percentage:", percentage, "%")
# Out:
# Area of rectangle = 50
# Simple Interest = 200.0
# Temperature in Fahrenheit = 98.6
# Average = 9.0
# Square = 25
# Cube = 125
# After swapping:
# a = 5
# b = 3
# Enter student name: shiya
# Enter roll number: 23
# Enter marks of Subject 1: 89
# Enter marks of Subject 2: 96
# Enter marks of Subject 3: 95
#
# ----- Student Report -----
# Student Name: shiya
# Roll Number: 23
# Total Marks: 280.0
# Percentage: 93.33333333333333 %
