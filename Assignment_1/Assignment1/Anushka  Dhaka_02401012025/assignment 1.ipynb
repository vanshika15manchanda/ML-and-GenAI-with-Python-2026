# %% [markdown]
# **ASSIGNMENT 1**

# %%
#1 Find area of rectangle.
print("QUESTION 1")
length=int(input("Enter the length of the rectangle: "))
breadth=int(input("Enter the breadth of the rectangle: "))
area=length*breadth
print("The area of the given rectangle is:",area,"unit sq")

#2 Find simple interest
print("QUESTION 2")
P=int(input("Enter the principle amount: "))
R=int(input("Enter the rate of interest: "))
T=int(input("Enter the time in years: "))
SI=(P*R*T)/100
print("The simple interest is: ",SI)
AMT=P+SI
print("The amount to be paid is: ",AMT)

#3 Convert temperature from Celsius to Fahrenheit
print("QUESTION 3")
cel=int(input("Enter the temp in celsius: "))
far=(cel*9/5)+32
print("The temp in fahrenheit is: ",far)

#4 Calculate average of 3 numbers.
print("QUESTION 4")
num1=int(input("Enter the 1st number: "))
num2=int(input("Enter the 2nd number: "))
num3=int(input("Enter the 3rd number: "))
avg=(num1+num2+num3)/3
print("The average of the 3 numbers is: ",avg)

#5 Find square and cube of a number
print("QUESTION 5")
num=int(input("Enter the number: "))
sq=num**2
cube=num**3
print("The square of the number is: ",sq)
print("The cube of the number is: ",cube)

#6 Swap two numbers without third variable
print("QUESTION 6")
a=int(input("Enter the 1st number: "))
b=int(input("Enter the 2nd number: "))
a=a+b
b=a-b
a=a-b
print("The numbers after swapping are: ",a,b)

#7. Create a Student Report Program that take student details using input(), Store marks in variables, Calculate total and percentage , Use comments, Use proper indentation
print("QUESTION 7")
name=input("Enter the name of the student: ")
roll=int(input("Enter the roll number of the student: "))
sub=int(input("Enter the number of subjects: "))
total=0
for i in range(sub):
  x = int(input("Enter the marks in subject " + str(i+1) + ": "))
  total=total+x
percentage=(total/(sub*100))*100
print("The total marks of the student is: ",total)
print("The percentage of the student is: ",percentage)
# Out:
# QUESTION 7
# Enter the name of the student: ana
# Enter the roll number of the student: 12
# Enter the number of subjects: 3
# Enter the marks in subject 1: 45
# Enter the marks in subject 2: 43
# Enter the marks in subject 3: 50
# The total marks of the student is:  138
# The percentage of the student is:  4600.0
