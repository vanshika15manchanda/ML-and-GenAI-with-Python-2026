# %%
x=int(input("length"))
y=int(input("breadth"))
area=x*y
print(area)
# Out:
# length4
# breadth5
# 20

# %%
p=int(input("principal amount"))
r=int(input("rate of interest"))
t=int(input("time"))
si=p*r*t/100
print(si)
# Out:
# principal amount1000
# rate of interest7
# time2
# 140.0

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
c=int(input("enter a number"))
avg=(a+b+c)/3
print(avg)
# Out:
# enter a number2
# enter a number3
# enter a number4
# 3.0

# %%
a=int(input("enter a number"))
square=a**2
cube=a**3
print(square)
print(cube)
# Out:
# enter a number2
# 4
# 8

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
a=a+b
b=a-b
a=a-b
print(a)
print(b)
# Out:
# enter a number3
# enter a number4
# 4
# 3

# %%
c=int(input("Enter temperature in celsius"))
f=c*9/5+32
print(f)
# Out:
# Enter temperature in celsius23
# 73.4

# %%
a=int(input("enter subject marks"))
b=int(input("enter subject marks"))
c=int(input("enter subject marks"))
d=int(input("enter subject marks"))
e=int(input("enter subject marks"))
total=a+b+c+d+e
percentage=total/5
print(total, " ", percentage)
# Out:
# enter subject marks80
# enter subject marks87
# enter subject marks90
# enter subject marks92
# enter subject marks95
# 444   88.8
