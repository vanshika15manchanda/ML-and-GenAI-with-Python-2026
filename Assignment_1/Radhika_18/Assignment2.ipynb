# %%
sum=0
for i in range(1,11):
  sum=sum+i
print(sum)
# Out:
# 55

# %%
num=int(input("enter a number"))
fact=1
for i in range(1,num+1):
  fact=fact*i
print("the factorial is ",fact)
# Out:
# enter a number5
# the factorial is  120

# %%
num=int(input("enter a number"))
a,b=0,1
for i in range(num):
  print(a, end=" ")
  a,b=b,a+b
# Out:
# enter a number4
# 0 1 1 2

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
c=int(input("enter a number"))
if a>=b and a>=c:
  print(a," is greatest")
elif b>=a and b>=c:
  print(b," is greatest")
else:
  print(c," is greatest")
# Out:
# enter a number10
# enter a number20
# enter a number23
# 23  is greatest

# %%
name=input("enter your name")
m1=int(input("enter marks of subject 1"))
m2=int(input("enter marks of subject 2"))
m3=int(input("enter marks of subject 3"))
m4=int(input("enter marks of subject 4"))
m5=int(input("enter marks of subject 5"))
percentage=(m1+m2+m3+m4+m5)/5
if percentage>=90:
  print(name," got A grade")
elif percentage>=80:
  print(name," got B grade")
elif percentage>=70:
  print(name," got C grade")
elif percentage>=60:
  print(name," got D grade")
else:
  print(name," got E grade")
# Out:
# enter your nameshweta
# enter marks of subject 185
# enter marks of subject 292
# enter marks of subject 394
# enter marks of subject 489
# enter marks of subject 595
# shweta  got A grade
