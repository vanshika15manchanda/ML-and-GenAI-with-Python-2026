# %%
l=10
b=10
area=l*b
print("area of rectangle = ",area)
# Out:
# area of rectangle =  100

# %%
p=1000
r=5
t=24
si=(p*r*t)/100
print("simple interest = ",si)
# Out:
# simple interest =  1200.0

# %%
temp_cel=float(input("enter temperature in celcius"))
temp_fah=(9/5)*temp_cel+32
print("temp in fahrenheit = ",temp_fah)
# Out:
# enter temperature in celcius97
# temp in fahrenheit =  206.6

# %%
a=10
b=20
c=30
avg=(a+b+c)/3
print("average = ",avg)
# Out:
# average =  20.0

# %%
sq=13**2
cube=13**3
print("square = ",sq,"\ncube = ",cube)
# Out:
# square =  169
# cube =  2197

# %%
a = 10
b = 20

a, b = b, a

print("a =", a)
print("b =", b)
# Out:
# a = 20
# b = 10

# %%
name=input("enter name = ")                          #name of student taken as input
maths=int(input("\nenter marks in maths = "))        #maths marks taken as input
science=int(input("\nenter marks in science = "))    #science marks taken as input
english=int(input("\nenter marks in english = "))    #english marks taken as input
total=maths+science+english                          #total marks calculated
percent=(total/300)*100                              #percentage calculated
print("\nstudent name = ",name)                      #print name
print("\ntotal marks = ",total)                      #total marks printed
print("\npercentage = ",percent)                     #percentage printed
# Out:
# enter name = moupi
#
# enter marks in maths = 98
#
# enter marks in science = 98
#
# enter marks in english = 100
#
# student name =  moupi
#
# total marks =  296
#
# percentage =  98.66666666666667
