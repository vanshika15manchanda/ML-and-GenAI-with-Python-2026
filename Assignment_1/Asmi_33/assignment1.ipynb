# %%
length=5
breadth=10
area=length*breadth
print(area)
# Out:
# 50

# %%
principal_sum=1000
rate=5
time=5
simple_interest=(principal_sum*rate*time)/100
print(simple_interest)
# Out:
# 250.0

# %%
temperature_in_C=35
temperature=(9/5)*temperature_in_C+32
print(temperature)
# Out:
# 95.0

# %%
a=5
b=6
c=7
average=(a+b+c)/2
print(average)
# Out:
# 9.0

# %%
n=2
square=n**2
cube=n**3
print(square)
print(cube)
# Out:
# 4
# 8

# %%
a=10
b=20
a,b=b,a
print(b)
print(a)
# Out:
# 10
# 20

# %%
#taking input
English=int(input("Enter marks of English:"))
Hindi=int(input("Enter marks of Hindi:"))
Maths=int(input("Enter marks of Maths:"))
SST=int(input("Enter marks of SST:"))
Science=int(input("Enter marks of Science:"))
#taking total
Total=English+Hindi+Maths+SST+Science
#taking percentage
Percentage=(Total/500)*100
print(Total)
print(Percentage)
# Out:
# Enter marks of English:97
# Enter marks of Hindi:98
# Enter marks of Maths:99
# Enter marks of SST:100
# Enter marks of Science:98
# 492
# 98.4
