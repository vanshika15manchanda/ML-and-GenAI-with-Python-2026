# %%
radius=int(input("enter the radius in cm"))
area=3.14*radius*radius
print("area of circle is ",area,"cm")
# Out:
# enter the radius in cm3
# area of circle is  28.259999999999998 cm

# %%
principal=int(input("enter the principal amount"))
rate=int(input("enter the rate"))
time=int(input("enter time"))
si=(principal*rate*time)/100
print("the simple interest is", si)
# Out:
# enter the principal amount12000
# enter the rate2
# enter time1
# the simple interest is 240.0

# %%
temp=int(input("enter the temperature in celcius"))
fahren=temp*9/5+32
print("the temperature in fahrenheit is",fahren)
# Out:
# enter the temperature in celcius35
# the temperature in fahrenheit is 95.0

# %%
print("enter three numbers")
n=3
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
num3=int(input("enter the third number"))
avg=(num1+num2+num3)/n
print("The average of the three numbers are", avg)
# Out:
# enter three numbers
# enter the first number1
# enter the second number2
# enter the third number3
# The average of the three numbers are 2.0

# %%
num=int(input("enter a number"))
square=num*num
cube=square*num
print("the square of the given numbers are",square)
print("the cube of the given numbers are",cube)
# Out:
# enter a number3
# the square of the given numbers are 9
# the cube of the given numbers are 27

# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))
a=a+b
b=a-b
a=a-b
print("the value of a", a)
print("the value of b",b)
# Out:
# enter the first number5
# enter the second number10
# the value of a 10
# the value of b 5

# %%
print("student report")
name=input("enter the name of the student:")
marks1=int(input("enter the marks of the first subject out of 100:"))
marks2=int(input("enter the marks of the second subject out of 100:"))
marks3=int(input("enter the marks of the third subject out of 100:"))
total=marks1+marks2+marks3
percentage=total/300*100
print("the total marks of the student",name,"is",total)
print("the percentage of the student is",percentage,"%")
# Out:
# student report
# enter the name of the student:christopher
# enter the marks of the first subject out of 100:98
# enter the marks of the second subject out of 100:97
# enter the marks of the third subject out of 100:100
# the total marks of the student christopher is 295
# the percentage of the student is 98.33333333333333 %
