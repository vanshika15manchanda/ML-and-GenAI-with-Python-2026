# %%
#1
#Find area of rectangle
l=float(input("enter the length of the rectangle : "))
b=float(input("enter the breadth of the rectangle : "))
area = l * b
print("the area of rectangle is : ",area)
# Out:
# enter the length of the rectangle : 12
# enter the breadth of the rectangle : 22
# the area of rectangle is :  264.0

# %%
#2
#Find simple interest
p=float(input("enter the principal amount :"))
r=float(input(" enter the rate of interest in percentage : "))
t=float(input("enter the time period : "))
SI= (p*r*t)/100
print("Simple Interest : ", SI)
# Out:
# enter the principal amount :10000
#  enter the rate of interest in percentage : 10
# enter the time period : 2
# Simple Interest :  2000.0

# %%
#3
#convert temperature from celsius to farenheit
c= float(input("enter temperature in celsius: "))
f= (9*c/5)+32
print("temperature in farenheit: ",f)
# Out:
# enter temperature in celsius22
# temperature in farenheit:  71.6

# %%
#4
#calculate the average of three numbers
a=float(input("enter first number : "))
b=float(input("enter second number : "))
c=float(input("enter third number : "))
avg= (a+b+c)/3
print("the average of the three numbers is: ",avg)
# Out:
# enter first number : 22
# enter second number : 23
# enter third number : 24
# the average of the three numbers is:  23.0

# %%
#5
#find the square and cube of a number
n=float(input("enter the number :"))
square_n= n*n
cube_n= n*n*n
print("the square is : ",square_n," ,the cube is: ",cube_n)
# Out:
# enter the number :11
# the square is :  121.0  ,the cube is:  1331.0

# %%
#6
#swap two numbers without third variable
a=float(input("enter a : "))
b=float(input("enter b : "))
a,b=b,a
print("a=",a)
print("b=",b)
# Out:
# enter first number : 11
# enter second number : 32
# a= 32.0
# b= 11.0

# %%
#7
#STUDENT REPORT PROGRAM
#input student details
name= input("enter name : ")
roll_number= int(input("enter student roll no. : "))
math=float(input("Enter marks scored in maths out of 100 : "))
phy=float(input("Enter marks scored in phy out of 100: "))
chem=float(input("Enter marks scored in chem out of 100: "))
#total marks scored
total_marksscored=math + phy + chem
avg= total_marksscored /3
percentage= (total_marksscored/300)*100
print(f"{name}'s average marks scored is ",avg,"and the percentage is ",percentage,"%")
# Out:
# enter name : om
# enter student roll no. : 42
# Enter marks scored in maths out of 100 : 99
# Enter marks scored in phy out of 100: 94
# Enter marks scored in chem out of 100: 91
# om's average marks scored is  94.66666666666667 and the percentage is  94.66666666666667 %
