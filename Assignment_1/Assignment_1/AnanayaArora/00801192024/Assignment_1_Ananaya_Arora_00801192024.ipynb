# %%
#find area of rectangle
length = float(input("Enter length: "))
width = float(input("Enter width: "))

area = length * width

print("Area of rectangle =", area)
# Out:
# Enter length: 15
# Enter width: 20
# Area of rectangle = 300.0

# %%
#find simple interest
principal = float(input("Enter Principal Amount: "))
rate = float(input("Enter Rate of Interest: "))
time = float(input("Enter Time (in year): "))

si = (principal*rate*time)/100;
print("Simple Interest =", si)
# Out:
# Enter Principal Amount: 1000
# Enter Rate of Interest: 5
# Enter Time (in year): 2
# Simple Interest = 100.0

# %%
#convert temperature from celsius to fahrenheit
celsius = float(input("Enter temperature in celsius: "))
fahrenheit = (celsius * 9/5) + 32
print('%.2f Celsius is: %0.2f Fahrenheit' %(celsius, fahrenheit))
# Out:
# Enter temperature in celsius: 32
# 32.00 Celsius is: 89.60 Fahrenheit

# %%
#calculate average of 3 numbers
nums1 = float(input("Enter first number: "))
nums2 = float(input("Enter second number: "))
nums3 = float(input("Enter third number: "))

avg = (nums1+nums2+nums3)/3
print("Average of three numbers =", avg)
# Out:
# Enter first number: 15
# Enter second number: 35
# Enter third number: 60
# Average of three numbers = 36.666666666666664

# %%
#find square and cube of a number
num = float(input("Enter a number: "))
square = num ** 2
cube = num ** 3
print("Square of", num, "is", square)
print("Cube of", num, "is", cube)
# Out:
# Enter a number: 15
# Square of 15.0 is 225.0
# Cube of 15.0 is 3375.0

# %%
#swap two numbers without third variable
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

num1, num2 = num2, num1

print("After swapping, first number =", num1)
print("After swapping, second number =", num2)
# Out:
# Enter first number: 17
# Enter second number: 19
# After swapping, first number = 19.0
# After swapping, second number = 17.0

# %%
#create a student report program that take students details using input(),
#store marks in variables, calculate total ans percentage, use comments, use proper indentation

#student report program

#taking student details
name = input("Enter Student name: ")
roll_no = input("Enter roll number: ")

#taking marks of three subjects
maths = float(input("Enter marks in Maths: "))
science = float(input("Enter marks in Science: "))
english = float(input("Enter marks in English: "))

#calculate total
total = maths + science + english

#calculate percentage
percentage = (total / 300) * 100

#displaying report
print("\n===== STUDENT REPORT =====")
print("Student Name:", name)
print("Roll No:", roll_no)
print("Maths:", maths)
print("Science:", science)
print("English:", english)
print("Total:", total)
print("Percentage:", percentage, "%")
# Out:
# Enter Student name: Ananaya Arora
# Enter roll number: 008
# Enter marks in Maths: 97
# Enter marks in Science: 99
# Enter marks in English: 94
#
# ===== STUDENT REPORT =====
# Student Name: Ananaya Arora
# Roll No: 008
# Maths: 97.0
# Science: 99.0
# English: 94.0
# Total: 290.0
# Percentage: 96.66666666666667 %
