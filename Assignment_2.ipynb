# %% [markdown]
# ASSIGNMENT 2 [WEEK-1]
#
# NAME: PURVA GARG
#
# ROLL NO.: 05301022025

# %% [markdown]
# Q1. Sum of first 10 natural numbers:

# %%
total = 0
for i in range(1, 11):
    total = total + i
print("Sum of ten natural numbers is: ", total)
