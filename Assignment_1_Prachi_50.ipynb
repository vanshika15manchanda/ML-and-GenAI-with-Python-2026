# %% [markdown]
# <a href="https://colab.research.google.com/github/Prachi-1717/ML-and-GenAI-with-Python-2026/blob/main/Assignment_1_Prachi_50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# 1.Find area of rectangle

# %%
l=2
b=4
Area = l*b
print(Area)
# Out:
# 8

# %% [markdown]
# 2.Find simple interest.

# %%
P=float(input("Enter the principal amount:"))
R=float(input("Enter the rate of interest:"))
T=float(input("Enter the time in years:"))
SI=(P*R*T)/100
print(SI)
# Out:
# Enter the principal amount:10000
# Enter the rate of interest:5
# Enter the time in years:3
# 1500.0

# %% [markdown]
# 3.Convert temperature from celsius to Fahrenheit.

# %%
c=float(input("Enter the temperature in celsius:"))
f=(c*9/5)+32
print(f)
# Out:
# Enter the temperature in celsius:38
# 100.4

# %% [markdown]
# 4.Calculate average of 3 numbers.

# %%
n1=int(input("Enter the first number:"))
n2=int(input("Enter the second number:"))
n3=int(input("Enter the third number:"))
average=(n1+n2+n3)/3
print(average)
# Out:
# Enter the first number:3
# Enter the second number:5
# Enter the third number:7
# 5.0

# %% [markdown]
# 5.Find square and cube of a number.

# %%
N=6
square=N**2
cube=N**3
print(square)
print(cube)
# Out:
# 36
# 216

# %% [markdown]
# 6.Swap two numbers without third Variable.

# %%
a=10
b=20
a,b=b,a
print("a=",a)
print("b=",b)
# Out:
# a= 20
# b= 10

# %% [markdown]
# 7.Create a Student Report Program that takes student details using input(),Store marks in variables,Calculate total and percentage ,Use comments,Use proper indentation.

# %%
student_details=input("Enter the student details:")# Provides essential details
roll_no=int(input("Enter roll no :"))
student_marks_total=int(input("Enter marks:")) # variable for student marks
total_percentage=(student_marks/500)*100 # for percentage
print(student_details)
print(roll_no)
print(student_marks_total)
print(total_percentage)
# Out:
# Enter the student details:Aryan studying in second division with roll no and marks respectively
# Enter roll no :15
# Enter marks:460
# Aryan studying in second division with roll no and marks respectively
# 15
# 460
# 91.2
