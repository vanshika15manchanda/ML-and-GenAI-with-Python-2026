# %%
# Khushi 09001012025
# Sum of 1st 10 natural number
Sum=0
for i in range(1,11):
  Sum +=i
print("Sum Of First Ten Natural Number:",Sum)
# Out:
# Sum Of First Ten Natural Number: 55

# %%
# Factorial of a number
a= int (input("Enter a number :"))
factorial=1
for i in range(a,1,-1):
  factorial = factorial*i
print("Factorial of a Number is:",factorial)
# Out:
# Enter a number :4
# Factorial of a Number is: 24

# %%
# Fibonacci Series
n=int(input("Enter the number of terms:"))
a=0
b=1
c=1
seq=[]
for _ in range (n):
  seq.append(a)
  a=b
  b=c
  c=a+b+c
print(seq)
# Out:
# Enter the number of terms:5
# [0, 1, 1, 3, 7]

# %%
# Largest among three
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
c=int(input("Enter third number:"))
max=a
if b>max:
  max=b
if c>max:
  max=c
print("Largest Number is ",max)
# Out:
# Enter first number:3
# Enter second number:6
# Enter third number:8
# Largest Number is  8

# %%
# Student Record System

while True:
  #student Details
  name=input("Enter Name :")
  roll=int(input("Enter Roll :"))

  #Marks Details
  maths=int(input("Enter Marks :"))
  physics=int(input("Enter Marks :"))
  chemistry=int(input("Enter Marks :"))

  #functions
  print("Percentage :",(maths+physics+chemistry)/3)
  if (maths+physics+chemistry)/3>90 :
    print("Grade is A")
  elif (maths+physics+chemistry)/3>80 :
    print("Grade is B")
  elif (maths+physics+chemistry)/3>70 :
    print("Grade is C")
  elif (maths+physics+chemistry)/3>60 :
    print("Grade is D")
  else :
    print("Grade is F")
  choice = input("\nDo you want to enter another student? (yes/no): ").lower()
  if choice != 'yes' and choice != 'y':
    break
# Out:
# Enter Name :Khushi
# Enter Roll :090
# Enter Marks :87
# Enter Marks :34
# Enter Marks :76
# Percentage : 65.66666666666667
# Grade is D
#
# Do you want to enter another student? (yes/no): yes
# Enter Name :Manvi
# Enter Roll :114
# Enter Marks :87
# Enter Marks :56
# Enter Marks :78
# Percentage : 73.66666666666667
# Grade is C
#
# Do you want to enter another student? (yes/no): no
