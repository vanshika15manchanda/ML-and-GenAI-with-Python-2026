# %% [markdown]
# Week1_Assignment2

# %%
#Sum of first n natural numbers
sum = 0
for i in range(1,11):
  sum=sum+i
print("Sum of n natural numbers is:",sum)
# Out:
# Sum of n natural numbers is: 55

# %%
#Factorial of a number
n = int(input("Enter number:"))
fact = 1
for i in range(1,n+1):
  fact = fact*i
print("Factorial of n is:",fact)
# Out:
# Enter number:4
# Factorial of n is: 24

# %%
#Fibonacci series
n = int(input("Enter number of terms:"))
a=0
b=1
print("The fibonacci series is:")
for i in range(n):
  print(a)
  a,b=b,a+b
# Out:
# Enter number of terms:5
# The fibonacci series is:
# 0
# 1
# 1
# 2
# 3

# %%
#Largest of three numbers
l = [20,40,30]
max = l[0]
for i in range(len(l)):
  if(l[i]>max):
    max=l[i]
print("The maximum value is:", max)
# Out:
# The maximum value is: 40

# %%
#Student result system
name = input("Enter student name:")
m1=int(input("Enter marks of 1st subject:"))
m2=int(input("Enter marks of 2nd subject:"))
m3=int(input("Enter marks of 3rd subject:"))
m4=int(input("Enter marks of 4th subject:"))
m5=int(input("Enter marks of 5th subject:"))
print("The total marks scored in five subjects out of 500 are:",m1+m2+m3+m4+m5)
p=((m1+m2+m3+m4+m5)/500)*100
print("The percentage of marks is:",p)
if(p<100 and p>=85):
  print("Grade A")
elif(p>=75 and p<90):
  print("Grade B")
elif(p>=60 and p<80):
  print("Grade C")
elif(p>=40 and p<65):
  print("Grade D")
else:
  print("Fail")
# Out:
# Enter student name:90
# Enter marks of 1st subject:86
# Enter marks of 2nd subject:91
# Enter marks of 3rd subject:80
# Enter marks of 4th subject:82
# Enter marks of 5th subject:83
# The total marks scored in five subjects out of 500 are: 422
# The percentage of marks is: 84.39999999999999
# Grade B
