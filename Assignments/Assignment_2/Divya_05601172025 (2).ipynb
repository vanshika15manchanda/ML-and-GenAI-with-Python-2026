# %% [markdown]
# # Python Exercise Solutions

# %% [markdown]
# ## Question 1: Print numbers from 1 to 10

# %%
for i in range(1, 11):
    print(i)

# %% [markdown]
# ## Question 2: Print first 10 even numbers

# %%
for i in range(2, 21, 2):
    print(i)

# %% [markdown]
# ## Question 3: Print multiplication table of any number

# %%
num = int(input('Enter a number: '))
for i in range(1, 11):
    print(f'{num} x {i} = {num*i}')

# %% [markdown]
# ## Question 4: Check whether a person is eligible to vote

# %%
age = int(input('Enter age: '))
if age >= 18:
    print('Eligible to vote')
else:
    print('Not eligible to vote')

# %% [markdown]
# ## Question 5: Display student grade based on marks

# %%
marks = float(input('Enter marks: '))
if marks >= 90:
    print('Grade A')
elif marks >= 75:
    print('Grade B')
elif marks >= 60:
    print('Grade C')
elif marks >= 40:
    print('Grade D')
else:
    print('Fail')

# %% [markdown]
# ## Question 6: Print factorial of a number

# %%
num = int(input('Enter a number: '))
fact = 1
for i in range(1, num + 1):
    fact *= i
print('Factorial =', fact)

# %% [markdown]
# ## Question 7: Reverse a number

# %%
num = int(input('Enter a number: '))
rev = 0
while num > 0:
    digit = num % 10
    rev = rev * 10 + digit
    num //= 10
print('Reversed number =', rev)
