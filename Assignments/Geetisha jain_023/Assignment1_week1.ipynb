# %%
#Area of rectangle
a=int(input("Enter length of rectangle:"))
b=int(input("Enter breadth of rectangle:"))
area=a*b
print("Area of rectangle is:",area)
# Out:
# Enter length of rectangle:12
# Enter breadth of rectangle:10
# Area of rectangle is: 120

# %%
#Calculate Simple Interest
PA=float(input("Enter principal amount:"))
R=float(input("Enter rate of interest:"))
T=float(input("Enter time(in years):"))
SimpleInterest=(PA*R*T)/100
print("Simple Interest:",SimpleInterest)
# Out:
# Enter principal amount:120000
# Enter rate of interest:5.8
# Enter time(in years):9
# Simple Interest: 62640.0

# %%
#Calculate Celcius to Fahreinheit
C=float(input("Enter Temperature:"))
F=(C*(9/5))+32
print("Temperature in Fahreinheit:",F)
# Out:
# Enter Temperature:79.97
# Temperature in Fahreinheit: 175.946

# %%
#Average of 3 numbers
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
c=int(input("Enter third number:"))
av=(a+b+c)/3
print("Average of 3 numbers:",av)
# Out:
# Enter first number:7
# Enter second number:8
# Enter third number:6
# Average of 3 numbers: 7.0

# %%
#Square and Cube of a number
a=int(input("Enter number:"))
square=a*a
cube=a*a*a
print("square of a number:",square)
print("cube of a number:",cube)
# Out:
# Enter number:12
# square of a number: 144
# cube of a number: 1728

# %%
#Swapping of numbers
a=int(input("Enter first number:"))
b=int(input("Enter second number:"))
a,b=b,a
print("Swapping numbers are:",a,b)
# Out:
# Enter first number:12
# Enter second number:34
# Swapping numbers are: 34 12

# %%
#Student Report
#Student details
name=input("Enter your name:")
RollNo=int(input("Enter your Enrollment no.:"))
#Student marks
maths=float(input("Enter Mathematics marks:"))
science=float(input("Enter Science marks:"))
english=float(input("Enter English marks:"))
#Total marks
total=maths+science+english
print("Total marks",total)
#Percentage
Percentage=(total/300)*100
print("Percentage",Percentage)
# Out:
# Enter your name:Geetisha Jain
# Enter your Enrollment no.:02301222025
# Enter Mathematics marks:98
# Enter Science marks:93
# Enter English marks:95
# Total marks 286.0
# Percentage 95.33333333333334
