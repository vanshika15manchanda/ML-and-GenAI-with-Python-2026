# %%
length= 10
breadth= 5
area= length*breadth
print("Area of rectangle= ", area)
# Out:
# Area of rectangle=  50

# %%
principle= 5000
rate= 10
time= 2
simple_interest= (principle*rate*time)/100
print("Simple Interest= ", simple_interest)
# Out:
# Simple Interest=  1000.0

# %%
celsius= 50
fahrenheit= (9/5)*celsius +32
print("Temperature in Fahrenheit= ", fahrenheit)
# Out:
# Temperature in Fahrenheit=  122.0

# %%
a= 5
b= 10
c= 3
avg= (a+b+c)/3
print("Average of 3, 5, 10= ", avg)
# Out:
# Average of 3, 5, 10=  6.0

# %%
x= 2
sq= x**2
cube= x**3
print("Square of 2= ", sq)
print("Cube of 2= ", cube)
# Out:
# Square of 2=  4
# Cube of 2=  8

# %%
a= 2
b= 3
a,b= b,a
print("a= ", a)
print("b= ", b)
# Out:
# a=  3
# b=  2

# %%
name= input("Enter your name: ")
math= int(input("Enter your Math marks: "))
science= int(input("Enter your Science marks: "))
total= math+science
percentage= (total/200)*100
print("Name= ", name)
print("Total= ", total)
print("Percentage= ", percentage, "%")
# Out:
# Enter your name: Saanvi Ahuja
# Enter your Math marks: 100
# Enter your Science marks: 100
# Name=  Saanvi Ahuja
# Total=  200
# Percentage=  100.0 %
