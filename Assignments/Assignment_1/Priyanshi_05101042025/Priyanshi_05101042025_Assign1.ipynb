# %%
#Area of rectangle
length=int(input("Enter the length"))
breadth=int(input("Enter the breadth"))
area=length*breadth
print("Area of rectangle is",area)
# Out:
# Enter the length5
# Enter the breadth3
# Area of rectangle is 15

# %%
#Simple Interest
p=int(input("Enter the principle amount"))
r=int(input("Enter the rate of interest"))
t=int(input("Enter the time"))
si=(p*r*t)/100
print("Simple Interest is:",si)
# Out:
# Enter the principle amount30
# Enter the rate of interest5
# Enter the time10
# Simple Interest is: 15.0

# %%
#Temperature from Celsius to Farenheit
cel=int(input("Enter the temperature in Celsius"))
far=(cel*9/5)+32
print("Temperature in Farenheit is:",far)
# Out:
# Enter the temperature in Celsius34
# Temperature in Farenheit is: 93.2

# %%
#Average of three numbers
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
c=int(input("Enter the third number"))
avg=(a+b+c)/3
print("Average of three numbers is:",avg)
# Out:
# Enter the first number5
# Enter the second number6
# Enter the third number7
# Average of three numbers is: 6.0

# %%
#Find square and cube of a number
num=int(input("Enter the number"))
square=num**2
cube=num**3
print("Square of the number is:",square)
print("Cube of the number is:",cube)
# Out:
# Enter the number4
# Square of the number is: 16
# Cube of the number is: 64

# %%
#Swap two numbers without theird variable
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
a=a+b
b=a-b
a=a-b
print("After swapping the numbers are:",a,b)
# Out:
# Enter the first number2
# Enter the second number3
# After swapping the numbers are: 3 2

# %%
#Student report program
name=input("Enter the name of student")
roll=int(input("Enter the roll number"))

#Marks
math=int(input("Enter the marks of maths"))
eng=int(input("Enter the marks of english"))
hin=int(input("Enter the marks of hindi"))
sci=int(input("Enter the marks of science"))

#Total marks
total=math+eng+hin+sci
print("Total marks obtained:",total)

#Percentage
per=total/4
print("Percentage:",per)
# Out:
# Enter the name of studentPriyanshi
# Enter the roll number05101042025
# Enter the marks of maths97
# Enter the marks of english90
# Enter the marks of hindi96
# Enter the marks of science94
# Total marks obtained: 377
# Percentage: 94.25
