# %%
length=float(input("enter length"))
breadth=float(input("enter breadth"))
area=length*breadth
print("area of rectangle is",area)
# Out:
# enter length3
# enter breadth4
# area of rectangle is 12.0

# %%
rate=float(input("enter rate"))
time=float(input("enter time in years"))
amount=float(input("enter principal amount"))
simple_interest=(amount*time*rate)/100
print("simple interest is",simple_interest)
# Out:
# enter rate4
# enter time in years6
# enter principal amount600
# simple interest is 144.0

# %%
Celsius=float(input("enter temp celcius"))
Fahrenheit=(9/5)*Celsius+32
print("temperature in farenheit is",Fahrenheit)
# Out:
# enter temp celcius56
# temperature in farenheit is 132.8

# %%
number1=float(input("enter number 1 "))
number2=float(input("enter number 2 "))
number3=float(input("enter number 3 "))
average=(number1+number2+number3)/3
print(average)
# Out:
# enter number 1 5
# enter number 2 6
# enter number 3 6
# 5.666666666666667

# %%
number=float(input("enter number "))
square=number*number
cube=number*number*number
print("square of number is",square)
print("cube of number is",cube)
# Out:
# enter number 3
# square of number is 9.0
# cube of number is 27.0

# %%
x=2
y=3
temp=x
x=y
y=temp
print("x is",x)
print("y is",y)
# Out:
# x is 3
# y is 2

# %%
#enter student name roll no
name = input("Enter student name: ")
roll_no = input("Enter roll number: ")
#input marks of 3 subjects
marks1=float(input("enter marks in maths"))
marks2=float(input("enter marks in science "))
marks3=float(input("enter marks in english "))
#total marks
total_marks=marks1+marks2+marks3
#percentage
percentage=(marks1+marks2+marks3/300)*100
#student report
print("Name:", name)
print("Roll Number:", roll_no)
print("Maths Marks:", marks1)
print("Science Marks:", marks2)
print("English Marks:", marks3)
# Out:
# Enter student name: saanvi
# Enter roll number: 56
# enter marks in maths99
# enter marks in science 98
# enter marks in english 98
# Name: saanvi
# Roll Number: 56
# Maths Marks: 99.0
# Science Marks: 98.0
# English Marks: 98.0
