# %%
#To find the area of rectangle
l = int(input("Enter the length of rectangle: "))
b = int(input("Enter the breadth of rectangle: "))
area = l*b
print("The area of rectangle is: ",area)
# Out:
# Enter the length of rectangle: 45
# Enter the breadth of rectangle: 67
# The area of rectangle is:  3015

# %%
P = float(input("Enter principal amount: "))
R = float(input("Enter rate: "))
T = int(input("Enter time (in years): "))
SI = (P*R*T)/100
print("Simple Interest = ",SI)
# Out:
# Enter principal amount: 9000
# Enter rate: 89
# Enter time (in years): 5
# Simple Interest =  40050.0

# %%
temp_cel = float(input("Enter temperature (in celsius): "))
temp_fah = (temp_cel*(9/5))+32
print("The temperature (in Fahrenheit) is: ",temp_fah)
# Out:
# Enter temperature (in celsius): 35.90
# The temperature (in Fahrenheit) is:  96.62

# %%
num = int(input("Enter a number: "))
sq = num ** 2
cube = num ** 3
print("The square of ",num," is ",sq,"\n","The cube of ",num," is ",cube)
# Out:
# Enter a number: 25
# The square of  25  is  625
#  The cube of  25  is  15625

# %%
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))
num3 = int(input("Enter number 3: "))
avg = (num1+num2+num3)/3
print("The average of three numbers is: ",avg)
# Out:
# Enter number 1: 21
# Enter number 2: 25
# Enter number 3: 45
# The average of three numbers is:  30.333333333333332

# %%
num1 = int(input("Enter number 1: "))#1
num2 = int(input("Enter number 2: "))#4
num1 = num1 + num2
num2 = num1 - num2
num1 = num1 - num2
print("Number 1 = ",num1,"\n","Number 2 = ",num2)
# Out:
# Enter number 1: 8
# Enter number 2: 9
# Number 1 =  9
#  Number 2 =  8

# %%
student_name = input("Enter your name: ")
marks_eng = float(input("Enter marks (Subject:English): "))
marks_maths = float(input("Enter marks (Subject:Maths): "))
marks_science = float(input("Enter marks (Subject:Science): "))
marks_hindi = float(input("Enter marks (Subject:Hindi): "))
marks_sst = float(input("Enter marks (Subject:Sst): "))
total_marks = marks_eng+marks_maths+marks_science+marks_hindi+marks_sst
total_percentage = (total_marks/500)*100
print("Percentage obtained: ",total_percentage)
# Out:
# Enter your name: archita
# Enter marks (Subject:English): 89
# Enter marks (Subject:Maths): 97
# Enter marks (Subject:Science): 91
# Enter marks (Subject:Hindi): 80
# Enter marks (Subject:Sst): 97
# Percentage obtained:  90.8
