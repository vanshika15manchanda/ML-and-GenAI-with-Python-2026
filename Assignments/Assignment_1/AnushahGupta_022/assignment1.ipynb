# %%
#create length and breadth variable
length=5
breadth=3

#calculate area
area=length*breadth

#print area
print("Area of the rectangle is:",area)
# Out:
# Area of the rectangle is: 15

# %%
#create Variables
principal=5000
rate=5
time=2

#Calculate simple interest
interest=(principal*rate*time)/100

#print the interest
print("The simple interest is:",interest)
# Out:
# The simple interest is: 500.0

# %%
#variable for value in celsius
celsius=26

#calculate temperature in farenheit
farenheit=(9*celsius)/5 +32

#print the temperature in farenheit
print("26 C in farenheit is:",farenheit)
# Out:
# 26 C in farenheit is: 78.8

# %%
#create three variables
var1=36
var2=76
var3=49

#calculate the average
average=(var1+var2+var3)/3

#print the average
print("the average is:",average)
# Out:
# the average is: 53.666666666666664

# %%
#create a variable
x=3

#Calculate square and cube
square=x*x
cube=x*x*x

#print the square and cube
print("square:",square)
print("cube:",cube)
# Out:
# square: 9
# cube: 27

# %%
#create two variables
a=34
b=56

#swap the values
a = a + b
b = a - b
a = a - b

#print the values
print("the new value of a is:",a)
print("the new value of b is:",b)
# Out:
# the new value of a is: 56
# the new value of b is: 34

# %%
#take student details as input
name = input("Enter student name:")
roll_no = input("Enter roll number:")

#take marks
maths = float(input("Enter maths marks:"))
science = float(input("Enter science marks:"))
english = float(input("Enter english marks:"))

#calculate total marks
total = maths + science + english

# calculate percentage
percentage = (total / 300) * 100

#print student report
print("Name:",name)
print("Roll Number:",roll_no)
print("Maths Marks:",maths)
print("Science Marks:",science)
print("English Marks:",english)
print("Total Marks:",total)
print("Percentage:",percentage, "%")
# Out:
# Enter student name:Anushah Gupta
# Enter roll number:022
# Enter maths marks:89
# Enter science marks:87
# Enter english marks:86
# Name: Anushah Gupta
# Roll Number: 022
# Maths Marks: 89.0
# Science Marks: 87.0
# English Marks: 86.0
# Total Marks: 262.0
# Percentage: 87.33333333333333 %
