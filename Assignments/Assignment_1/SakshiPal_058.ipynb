# %%
lenght = 5
breadth = 3
area = lenght*breadth
print(area)
# Out:
# 15

# %%
principle = 6000
rate = 5
time = 3
simple_interest = (principle*rate*time)/100
print(simple_interest)
# Out:
# 900.0

# %%
temprature_celcius= 34
temprature_farenheit = (temprature_celcius*9/5)+32
print(temprature_farenheit)
# Out:
# 93.2

# %%
number_1 = int(input("first number:"))
number_2 = int(input("second number:"))
number_3 = int(input("third number:"))
average = (number_1+number_2+number_3)/3
print(average)
# Out:
# first number:3
# second number:5
# third number:7
# 5.0

# %%
number = int(input("enter the number:"))
square_of_number = number**2
cube_of_number = number**3
print(square_of_number)
print(cube_of_number)
# Out:
# enter the number:4
# 16
# 64

# %%
x = 5
y = 9
x,y= y,x
print(x)
print(y)
# Out:
# 9
# 5

# %%
#student deatil
name = input("enter your name:")
roll_no = input("enter your roll no:")
# enter marks
mark = input("enter your mark:")
oops = input("enter your oops mark:")
physics = input("enter your physics mark:")
maths = input("enter your maths mark:")
#calculte total marks
total_mark = int(oops)+int(physics)+int(maths)
print(total_mark)
print("name:",name)
print("roll no:",roll_no)
print("mark:",mark)
# Out:
# enter your name:Sakshi Pal
# enter your roll no:058
# enter your mark:3
# enter your oops mark:59
# enter your physics mark:58
# enter your maths mark:54
# 171
# name: Sakshi Pal
# roll no: 058
# mark: 3
