# %%
#area of rectangle
a=float(input("enter length of rectangle:" ))
b=float(input("enter breadth of rectangle:" ))
print(a*b)
# Out:
# enter length of rectangle: 5
# enter breadth of rectangle: 4
# 20.0

# %%
#find simple interest
a=float(input("enter principle amount:" ))
b=float(input("rate of interest is:" ))
c=float(input("time of loan(in years):"))
print((a*b*c)/100)
# Out:
# enter principle amount: 200
# rate of interest is: 3
# time of loan(in years): 2
# 12.0

# %%
#covert temperature from celcius to fahrenheit
a=float(input("enter temperature in celcius:" ))
f=(a*1.8)+32
print("the temperature in degree fahrenheit is:", f)
# Out:
# enter temperature in celcius: 25
# the temperature in degree fahrenheit is: 77.0

# %%
#calculate the average of three numbers 
a=int(input("enter first number:" ))
b=int(input("enter second number:" ))
c=int(input("enter third number:" ))
d=(a+b+c)/3
print(d)
# Out:
# enter first number: 2
# enter second number: -6
# enter third number: 5
# 0.3333333333333333

# %%
#find square and cube of a number
a=int(input("enter the number:" ))
print("square of number is:",a*a)
print("cube of number is:",a**3)
# Out:
# enter the number: 5
# square of number is: 25
# cube of number is: 125

# %%
#swap two numbers without third variable 
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

a, b = b, a

print("a =", a)
print("b =", b)
# Out:
# Enter first number:  3
# Enter second number:  5
# a = 5
# b = 3

# %%
"""create a student report program that takes student details using input(), store marks in variables, calculate total and percentage,use comments,
use proper indentation"""

# Taking student details
name = input("Enter student name: ")
roll_no = input("Enter roll number: ")

# Taking marks of three subjects
mark1 = float(input("Enter marks in Subject 1 (out of 100): "))
mark2 = float(input("Enter marks in Subject 2 (out of 100): "))
mark3 = float(input("Enter marks in Subject 3 (out of 100): "))

# Calculating total marks
total = mark1 + mark2 + mark3

# Calculating percentage
percentage= ((mark1+mark2+mark3)/300)*100
# Displaying report
print("----- STUDENT REPORT -----")
print("Name:", name)
print("Roll Number:", roll_no)
print("Subject 1 Marks:", mark1)
print("Subject 2 Marks:", mark2)
print("Subject 3 Marks:", mark3)
print("Total Marks:", total)
print("Percentage:", percentage, "%")
# Out:
# Enter student name:  Riddhima Sharma
# Enter roll number:  10301182025
# Enter marks in Subject 1 (out of 100):  95
# Enter marks in Subject 2 (out of 100):  97
# Enter marks in Subject 3 (out of 100):  98
# ----- STUDENT REPORT -----
# Name: Riddhima Sharma
# Roll Number: 10301182025
# Subject 1 Marks: 95.0
# Subject 2 Marks: 97.0
# Subject 3 Marks: 98.0
# Total Marks: 290.0
# Percentage: 96.66666666666667 %
