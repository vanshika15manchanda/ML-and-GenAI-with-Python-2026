# %%
#area of rectangle
a=int(input("Enter length of the rectangle"))
b=int(input("enter breadth of the rectangle"))
print("area of rectangle is= ", a*b)
# Out:
# Enter length of the rectangle5
# enter breadth of the rectangle8
# area of rectangle is=  40

# %%
#Finding simple intrest
P=int(input("Enter principal amount "))
R=float(input("Enter rate of intrest "))
T=int(input("Enter time "))
print("simple intrest = ", (P*R*T)/100)
# Out:
# Enter principal amount 10000
# Enter rate of intrest 5.2
# Enter time 2
# simple intrest =  1040.0

# %%
#celsius to farhenhiet
C=float(input("enter temperature in celsius= "))
print("the temperature in farhenheit is= ",C*9/5+32)
# Out:
# enter temperature in celsius= 44
# the temperature in farhenheit is=  111.2

# %%
#average of 3 numbers
A=int(input("First number"))
B=int(input("Second number"))
C=int(input("Third number"))
print("the average of numbers is= ",A+B+C/3 )
# Out:
# First number5
# Second number6
# Third number7
# the average of numbers is=  13.333333333333334

# %%
#Find square and cube root of a number
Num=int(input("enter number "))
Sqrt=Num** 2
Cbrt=Num** 3
print("the square root is= ",Sqrt)
print("the cube root is ",Cbrt)
# Out:
# enter number 5
# the square root is=  25
# the cube root is  125

# %%
#swapping
A=int(input("Enter first number "))
B=int(input("Enter Second number "))
A,B=B,A
print("after swapping")
print("A= ",A)
print("B= ",B)
# Out:
# Enter first number 5
# Enter Second number 9
# after swapping
# A=  9
# B=  5

# %%
from ast import Name
#student report programme
#taling student details
name=input("Enter student name ")
RollNo =input("enter roll no. ")
#storing marks
Maths=int(input("Enter marks in maths "))
Chem=int(input("enter marks in chemistry " ))
Phy=int(input("enter marks in physics "))
#calculating total
Total=Maths+Chem+Phy
#Calculating percentage
Percentage=Total/300*100
#displaying result
print("Name= ",Name)
print("Roll No.= ",RollNo)
print("total marks= ",Total)
print("Percentage= ",Percentage)
# Out:
# Enter student name Apala Kapoor
# enter roll no. 02601012025
# Enter marks in maths 98
# enter marks in chemistry 96
# enter marks in physics 97
# total marks=  291
# Percentage=  97.0
