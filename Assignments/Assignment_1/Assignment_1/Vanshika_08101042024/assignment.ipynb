# %%
length = 5;
breadth = 3;
Area = length * breadth;
print("Area of rectangle:", Area)
# Out:
# Area of rectangle: 15

# %%
principal = 5000;
rate = 8;
time = 2; # in years
simple_interest = (principal*rate*time)/100;
print("Simple interest:", simple_interest)
# Out:
# Simple interest: 800.0

# %%
temp_celsius = 25;
temp_fahrenheit = (9/5)*temp_celsius+32;
print(temp_celsius,"degree celsius is ",temp_fahrenheit)
# Out:
# 25 degree celsius is  77.0

# %%
num_1 = 2;
num_2 = 42;
num_3 = 100;
avg = (num_1 + num_2 + num_3)/3;
print("Average:", avg)
# Out:
# Average: 48.0

# %%
num = 3;
sqr = num**2;
cube = num**3;
print("Square:",sqr,"; Cube:",cube)
# Out:
# Square: 9 ; Cube: 27

# %%
a = 1;
b = 2;
print("Numbers before swapping")
print("a:",a,"; b:",b)
a,b = b,a;
print("Numbers after swapping")
print("a:",a,"; b:",b)
# Out:
# Numbers before swapping
# a: 1 ; b: 2
# Numbers after swapping
# a: 2 ; b: 1

# %%
#Student details
name = input("Enter the student's name:")
#marks are out of 100
phy = int(input("Enter the student's physics marks:"))
chem = int(input("Enter the student's chemistry marks:"))
maths = int(input("Enter the student's maths marks:"))
total = phy + chem + maths; # total marks
percentage = (total/300)*100; #percentage
print("Total marks:",total)
print("Percentage",percentage)
# Out:
# Enter the student's name:Vanshika
# Enter the student's physics marks:100
# Enter the student's chemistry marks:99
# Enter the student's maths marks:98
# Total marks: 297
# Percentage 99.0
