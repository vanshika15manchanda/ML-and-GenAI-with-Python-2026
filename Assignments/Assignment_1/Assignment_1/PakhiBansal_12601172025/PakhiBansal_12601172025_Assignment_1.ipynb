# %%
len = 4

# %%
bredth = 3

# %%
area = len * bredth

# %%
print(area)
# Out:
# 12

# %%
principle = 3000

# %%
rate = 10

# %%
time = 3

# %%
simple_interest = (principle * rate * time)/100

# %%
print(simple_interest)
# Out:
# 900.0

# %%
celcius = 100

# %%
far = ((9*celcius)/5) + 32

# %%
print(far)
# Out:
# 212.0

# %%
first = 45

# %%
second = 65

# %%
third = 98

# %%
avg = (first + second + third)/3

# %%
print(avg)
# Out:
# 69.33333333333333

# %%
a = 6

# %%
sq = a * a

# %%
cube = a*a*a

# %%
print(sq)
# Out:
# 36

# %%
print(cube)
# Out:
# 216

# %%
a = 6

# %%
b = 3

# %%
a,b = b,a

# %%
print(a,b)
# Out:
# 3 6

# %%
marks_1 = int(input("enter maths marks:"))
marks_2 = int(input("enter science marks:"))
marks_3 = int(input("enter hindi marks:"))
marks_4 = int(input("enter english marks:"))

def function(marks_1,marks_2,marks_3,marks_4):
  total = marks_1+marks_2+marks_3+marks_4
  print("total score" , total)
  percentage = (total/400)*100
  print("your percentage is" , percentage)

function(marks_1,marks_2,marks_3,marks_4)
# Out:
# enter maths marks:89
# enter science marks:90
# enter hindi marks:87
# enter english marks:98
# total score 364
# your percentage is 91.0
