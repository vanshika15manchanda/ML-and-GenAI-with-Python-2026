# %%
# Khushi 09001012025
# Area of Rectangle
a=int(input("enter length :"))
b=int(input("enter width :"))
print("Area of Rectangle ",a*b)
# Out:
# enter length :2
# enter width :3
# Area of Rectangle  6

# %%
# Simple Interest
p=int(input("enter Principle :"))
r=int(input("enter Interest Rate :"))
t=int(input("enter Time :"))
print("Sample Interest :",(p*r*t)/100)
# Out:
# enter Principle :23
# enter Interest Rate :45
# enter Time :33
# Sample Interest : 341.55

# %%
# Temprature conversion: celsius to fahrenheit
a=int(input("enter temp in celsius :"))
print("Temprature in fahrenheit",(a+9/5)+32)
# Out:
# enter temp in celsius :273
# Temprature in fahrenheit 306.8

# %%
# Avg of 3 numbers
a=int(input("enter number :"))
b=int(input("enter number :"))
c=int(input("enter number :"))
print("Average of three numbers",(a+b+c)/3)
# Out:
# enter number :1
# enter number :2
# enter number :3
# Average of three numbers 2.0

# %%
# square
a=int(input("enter number :"))
print("square of number is ",a**2)
#cube
print("cube of number is ",a**3)
# Out:
# enter number :2
# square of number is  4
# cube of number is  8

# %%
#Swaping Two Number Without Swaping
a=int(input("enter 1st number :"))
b=int(input("enter 2nd number :"))
b=a+b
a=b-a
b=b-a
print("1st number is ",a)
print("2nd number is ",b)
# Out:
# enter 1st number :2
# enter 2nd number :4
# 1st number is  4
# 2nd number is  2

# %%
#Student Record Program

#student Details
name=input("Enter Name :")
roll=int(input("Enter Roll :"))

#Marks Details
maths=int(input("Enter Marks :"))
physics=int(input("Enter Marks :"))
chemistry=int(input("Enter Marks :"))

#functions
print("Total of marks :",maths+physics+chemistry)
print("Percentage :",((maths+physics+chemistry)/300)*100)
# Out:
# Enter Name :xyz
# Enter Roll :62
# Enter Marks :76
# Enter Marks :29
# Enter Marks :83
# Total of marks : 188
# Percentage : 62.66666666666667
