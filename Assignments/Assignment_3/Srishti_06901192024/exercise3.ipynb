# %%
#Q1 print your name
def print_name():
    print("Srishti")  
print_name()
# Out:
# Srishti

# %%
#Q2 func to add 2 nos
def add_numbers(a, b):
    return a + b
result = add_numbers(5, 3)
print("Sum:", result)
# Out:
# Sum: 8

# %%
#Q3 function that accepts a student's name and prints a welcome message
def welcome_student(name):
    print("Welcome,", name + "!")
welcome_student("Srishti")
# Out:
# Welcome, Srishti!

# %%
#Q4 func to find sq of a no
def square_n(num):
    return num * num
print("Square:", square_n(4))
# Out:
# Square: 16
